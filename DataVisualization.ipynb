# %% [markdown]
# <span style="font-size:30px"><b>Importing Libraries</b></span>

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# <span style="font-size:30px"><b>Load Dataset</b></span>

# %%
from sklearn.datasets import load_iris

iris = load_iris()
df = pd.DataFrame(iris.data, columns=iris.feature_names)
df['species'] = pd.Categorical.from_codes(iris.target, iris.target_names)

sns.set(style='whitegrid')

# %% [markdown]
# <span style="font-size:30px"><b>Plot Pairplot</b></span>

# %%
sns.pairplot(df, hue='species', height=2.5)
plt.suptitle("Pairplot of Iris Dataset", y=1.02)
plt.show()

# %% [markdown]
# <span style="font-size:30px"><b>Ploat Correlation Heatmap</b></span>

# %%
plt.figure(figsize=(8, 5))
sns.heatmap(df.drop('species', axis=1).corr(), annot=True, cmap='coolwarm')
plt.title("Feature Correlation in Iris Dataset")
plt.show()
